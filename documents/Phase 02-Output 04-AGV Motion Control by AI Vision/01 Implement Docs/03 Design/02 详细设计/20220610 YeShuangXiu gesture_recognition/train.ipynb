# %%
from sklearn.model_selection import train_test_split
from tensorflow.keras.utils import to_categorical
import cv2
import numpy as np
import os
from matplotlib import pyplot as plt
import time
import mediapipe as mp
# Out:
# d:\Anaconda\package\lib\site-packages\numpy\_distributor_init.py:30: UserWarning: loaded more than 1 DLL from .libs:
# d:\Anaconda\package\lib\site-packages\numpy\.libs\libopenblas.PYQHXLVVQ7VESDPUVUADXEVJOBGHJPAY.gfortran-win_amd64.dll
# d:\Anaconda\package\lib\site-packages\numpy\.libs\libopenblas.QVLO2T66WEPI7JZ63PS3HMOHFEY472BC.gfortran-win_amd64.dll
# d:\Anaconda\package\lib\site-packages\numpy\.libs\libopenblas.WCDJNK7YVMPZQ2ME2ZZHJJRJ3JIKNDB7.gfortran-win_amd64.dll
#   warnings.warn("loaded more than 1 DLL from .libs:"

# %%
actions = np.array(['start', 'end', 'turn_left','turn_right', 'go_forward', 'go_backward'])
label_map = {label:num for num, label in enumerate(actions)}

# %%
# Path for exported data, numpy arrays
DATA_PATH = os.path.join('MP_Data') 
# Thirty videos worth of data
no_sequences = 360
# Videos are going to be 30 frames in length
sequence_length = 5
sequences, labels = [], []
for action in actions:
    for sequence in np.array(os.listdir(os.path.join(DATA_PATH, action))).astype(int):
        window = []
        for frame_num in range(sequence_length):
            res = np.load(os.path.join(DATA_PATH, action, str(sequence), "{}.npy".format(frame_num)))
            window.append(res)
        sequences.append(window)
        labels.append(label_map[action])
X = np.array(sequences)
y = to_categorical(labels).astype(int)
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.05)

# %%
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import LSTM, Dense
from tensorflow.keras.callbacks import TensorBoard
from tensorflow.keras import regularizers

# %%
log_dir = os.path.join('Logs')
tb_callback = TensorBoard(log_dir=log_dir)

# %%
model = Sequential()
model.add(LSTM(64, return_sequences=True, activation='relu', input_shape=(5,126)))
model.add(LSTM(128, return_sequences=True, activation='relu'))
model.add(LSTM(64, return_sequences=False, activation='relu'))
model.add(Dense(64, activation='relu',kernel_regularizer=regularizers.l2(0.01),
                activity_regularizer=regularizers.l1(0.01)))
model.add(Dense(32, activation='relu',kernel_regularizer=regularizers.l2(0.01),
                activity_regularizer=regularizers.l1(0.01)))
model.add(Dense(actions.shape[0], activation='softmax'))
model.compile(optimizer='Adam', loss='categorical_crossentropy', metrics=['categorical_accuracy'])

# %%
model.fit(X_train, y_train, epochs=2000, validation_data=(X_test, y_test), callbacks=[tb_callback], shuffle=True)
# Out:
# Epoch 1/2000
# 65/65 [==============================] - 7s 48ms/step - loss: 2.6387 - categorical_accuracy: 0.3054 - val_loss: 1.9992 - val_categorical_accuracy: 0.4259
# Epoch 2/2000
# 65/65 [==============================] - 1s 9ms/step - loss: 1.8152 - categorical_accuracy: 0.4494 - val_loss: 1.6076 - val_categorical_accuracy: 0.4907
# Epoch 3/2000
# 65/65 [==============================] - 1s 9ms/step - loss: 1.3852 - categorical_accuracy: 0.5946 - val_loss: 1.2828 - val_categorical_accuracy: 0.4722
# Epoch 4/2000
# 65/65 [==============================] - 1s 9ms/step - loss: 1.1827 - categorical_accuracy: 0.6450 - val_loss: 1.4014 - val_categorical_accuracy: 0.4167
# Epoch 5/2000
# 65/65 [==============================] - 1s 11ms/step - loss: 1.0606 - categorical_accuracy: 0.6852 - val_loss: 0.8632 - val_categorical_accuracy: 0.7870
# Epoch 6/2000
# 65/65 [==============================] - 1s 11ms/step - loss: 0.8296 - categorical_accuracy: 0.8133 - val_loss: 0.6754 - val_categorical_accuracy: 0.8981
# Epoch 7/2000
# 65/65 [==============================] - 1s 12ms/step - loss: 0.7759 - categorical_accuracy: 0.8243 - val_loss: 0.5726 - val_categorical_accuracy: 0.9259
# Epoch 8/2000
# 65/65 [==============================] - 1s 11ms/step - loss: 0.5295 - categorical_accuracy: 0.9550 - val_loss: 0.4418 - val_categorical_accuracy: 1.0000
# Epoch 9/2000
# 65/65 [==============================] - 1s 10ms/step - loss: 0.4550 - categorical_accuracy: 0.9515 - val_loss: 0.5124 - val_categorical_accuracy: 0.9907
# Epoch 10/2000
# 65/65 [==============================] - 1s 11ms/step - loss: 0.5168 - categorical_accuracy: 0.9395 - val_loss: 0.3675 - val_categorical_accuracy: 0.9815
# Epoch 11/2000
# 65/65 [==============================] - 1s 11ms/step - loss: 0.4251 - categorical_accuracy: 0.9513 - val_loss: 0.4145 - val_categorical_accuracy: 0.9537
# Epoch 12/2000
# 65/65 [==============================] - 1s 11ms/step - loss: 0.3755 - categorical_accuracy: 0.9636 - val_loss: 0.3904 - val_categorical_accuracy: 0.9352
# Epoch 13/2000
# 65/65 [==============================] - 1s 10ms/step - loss: 0.3328 - categorical_accuracy: 0.9723 - val_loss: 0.2675 - val_categorical_accuracy: 1.0000
# Epoch 14/2000
# 65/65 [==============================] - 1s 9ms/step - loss: 0.3075 - categorical_accuracy: 0.9820 - val_loss: 0.2705 - val_categorical_accuracy: 0.9907
# Epoch 15/2000
# 65/65 [==============================] - 1s 9ms/step - loss: 0.2970 - categorical_accuracy: 0.9842 - val_loss: 0.2505 - val_categorical_accuracy: 0.9907
# Epoch 16/2000
# 65/65 [==============================] - 1s 9ms/step - loss: 0.2667 - categorical_accuracy: 0.9887 - val_loss: 0.2391 - val_categorical_accuracy: 0.9907
# Epoch 17/2000
# 65/65 [==============================] - 1s 9ms/step - loss: 0.2397 - categorical_accuracy: 0.9944 - val_loss: 0.2254 - val_categorical_accuracy: 1.0000
# Epoch 18/2000
# 65/65 [==============================] - 1s 8ms/step - loss: 0.2512 - categorical_accuracy: 0.9869 - val_loss: 0.8473 - val_categorical_accuracy: 0.6852
# Epoch 19/2000
# 65/65 [==============================] - 1s 9ms/step - loss: 0.5741 - categorical_accuracy: 0.8568 - val_loss: 0.2460 - val_categorical_accuracy: 0.9907
# Epoch 20/2000
# 65/65 [==============================] - 1s 8ms/step - loss: 0.2706 - categorical_accuracy: 0.9826 - val_loss: 0.2918 - val_categorical_accuracy: 0.9630
# Epoch 21/2000
# 65/65 [==============================] - 1s 9ms/step - loss: 0.2258 - categorical_accuracy: 0.9926 - val_loss: 0.1955 - val_categorical_accuracy: 1.0000
# Epoch 22/2000
# 65/65 [==============================] - 1s 8ms/step - loss: 0.2434 - categorical_accuracy: 0.9812 - val_loss: 0.1914 - val_categorical_accuracy: 1.0000
# Epoch 23/2000
# 65/65 [==============================] - 0s 8ms/step - loss: 0.2798 - categorical_accuracy: 0.9697 - val_loss: 0.1991 - val_categorical_accuracy: 1.0000
# Epoch 24/2000
# 65/65 [==============================] - 1s 9ms/step - loss: 0.2042 - categorical_accuracy: 0.9935 - val_loss: 0.2865 - val_categorical_accuracy: 0.9630
# Epoch 25/2000
# 65/65 [==============================] - 1s 11ms/step - loss: 0.2451 - categorical_accuracy: 0.9808 - val_loss: 0.1858 - val_categorical_accuracy: 1.0000
# Epoch 26/2000
# 65/65 [==============================] - 1s 8ms/step - loss: 0.1896 - categorical_accuracy: 0.9936 - val_loss: 0.1665 - val_categorical_accuracy: 1.0000
# Epoch 27/2000
# 65/65 [==============================] - 1s 9ms/step - loss: 0.1883 - categorical_accuracy: 0.9913 - val_loss: 0.1646 - val_categorical_accuracy: 1.0000
# Epoch 28/2000
# 65/65 [==============================] - 1s 9ms/step - loss: 0.1820 - categorical_accuracy: 0.9929 - val_loss: 0.1666 - val_categorical_accuracy: 1.0000
# Epoch 29/2000
# 65/65 [==============================] - 1s 9ms/step - loss: 0.1703 - categorical_accuracy: 0.9959 - val_loss: 0.1538 - val_categorical_accuracy: 1.0000
# Epoch 30/2000
# 65/65 [==============================] - 0s 8ms/step - loss: 0.1790 - categorical_accuracy: 0.9922 - val_loss: 0.1467 - val_categorical_accuracy: 1.0000
# Epoch 31/2000
# 65/65 [==============================] - 1s 9ms/step - loss: 0.1601 - categorical_accuracy: 0.9947 - val_loss: 0.2804 - val_categorical_accuracy: 0.9444
# Epoch 32/2000
# 65/65 [==============================] - 1s 9ms/step - loss: 0.3003 - categorical_accuracy: 0.9553 - val_loss: 0.1604 - val_categorical_accuracy: 1.0000
# Epoch 33/2000
# 65/65 [==============================] - 1s 9ms/step - loss: 0.2536 - categorical_accuracy: 0.9668 - val_loss: 0.1421 - val_categorical_accuracy: 1.0000
# Epoch 34/2000
# 65/65 [==============================] - 1s 9ms/step - loss: 0.1615 - categorical_accuracy: 0.9926 - val_loss: 0.1372 - val_categorical_accuracy: 1.0000
# Epoch 35/2000
# 65/65 [==============================] - 1s 9ms/step - loss: 0.1415 - categorical_accuracy: 0.9977 - val_loss: 0.2193 - val_categorical_accuracy: 0.9722
# Epoch 36/2000
# 65/65 [==============================] - 1s 8ms/step - loss: 0.1588 - categorical_accuracy: 0.9903 - val_loss: 0.1305 - val_categorical_accuracy: 1.0000
# Epoch 37/2000
# 65/65 [==============================] - 1s 9ms/step - loss: 0.1482 - categorical_accuracy: 0.9948 - val_loss: 0.1271 - val_categorical_accuracy: 1.0000
# Epoch 38/2000
# 65/65 [==============================] - 1s 8ms/step - loss: 0.1564 - categorical_accuracy: 0.9899 - val_loss: 0.2044 - val_categorical_accuracy: 0.9722
# Epoch 39/2000
# 65/65 [==============================] - 1s 9ms/step - loss: 0.1790 - categorical_accuracy: 0.9862 - val_loss: 0.1279 - val_categorical_accuracy: 1.0000
# Epoch 40/2000
# 65/65 [==============================] - 1s 9ms/step - loss: 0.1306 - categorical_accuracy: 0.9979 - val_loss: 0.1212 - val_categorical_accuracy: 1.0000
# Epoch 41/2000
# 65/65 [==============================] - 1s 9ms/step - loss: 0.1310 - categorical_accuracy: 0.9963 - val_loss: 0.1434 - val_categorical_accuracy: 0.9907
# Epoch 42/2000
# 65/65 [==============================] - 1s 9ms/step - loss: 0.1521 - categorical_accuracy: 0.9905 - val_loss: 0.1269 - val_categorical_accuracy: 1.0000
# Epoch 43/2000
# 65/65 [==============================] - 1s 10ms/step - loss: 0.1339 - categorical_accuracy: 0.9954 - val_loss: 0.1224 - val_categorical_accuracy: 1.0000
# Epoch 44/2000
# 65/65 [==============================] - 1s 10ms/step - loss: 0.1498 - categorical_accuracy: 0.9874 - val_loss: 0.1148 - val_categorical_accuracy: 1.0000
# Epoch 45/2000
# 65/65 [==============================] - 1s 9ms/step - loss: 0.1410 - categorical_accuracy: 0.9899 - val_loss: 0.1211 - val_categorical_accuracy: 1.0000
# Epoch 46/2000
# 65/65 [==============================] - 1s 9ms/step - loss: 0.1540 - categorical_accuracy: 0.9883 - val_loss: 0.2364 - val_categorical_accuracy: 0.9352
# Epoch 47/2000
# 65/65 [==============================] - 1s 8ms/step - loss: 0.2275 - categorical_accuracy: 0.9651 - val_loss: 0.1337 - val_categorical_accuracy: 0.9907
# Epoch 48/2000
# 65/65 [==============================] - 1s 9ms/step - loss: 0.1278 - categorical_accuracy: 0.9956 - val_loss: 0.1104 - val_categorical_accuracy: 1.0000
# Epoch 49/2000
# 65/65 [==============================] - 1s 11ms/step - loss: 0.1274 - categorical_accuracy: 0.9939 - val_loss: 0.1064 - val_categorical_accuracy: 1.0000
# Epoch 50/2000
# 65/65 [==============================] - 0s 7ms/step - loss: 0.1118 - categorical_accuracy: 0.9984 - val_loss: 0.1056 - val_categorical_accuracy: 1.0000
# Epoch 51/2000
# 65/65 [==============================] - 1s 9ms/step - loss: 0.1119 - categorical_accuracy: 0.9959 - val_loss: 0.1033 - val_categorical_accuracy: 1.0000
# Epoch 52/2000
# 65/65 [==============================] - 1s 9ms/step - loss: 0.1141 - categorical_accuracy: 0.9963 - val_loss: 0.1036 - val_categorical_accuracy: 1.0000
# Epoch 53/2000
# 65/65 [==============================] - 1s 8ms/step - loss: 0.1152 - categorical_accuracy: 0.9973 - val_loss: 0.1022 - val_categorical_accuracy: 1.0000
# Epoch 54/2000
# 65/65 [==============================] - 1s 9ms/step - loss: 0.1206 - categorical_accuracy: 0.9949 - val_loss: 0.1066 - val_categorical_accuracy: 1.0000
# Epoch 55/2000
# 65/65 [==============================] - 0s 8ms/step - loss: 0.1101 - categorical_accuracy: 0.9953 - val_loss: 0.1369 - val_categorical_accuracy: 0.9907
# Epoch 56/2000
# 65/65 [==============================] - 1s 9ms/step - loss: 0.1875 - categorical_accuracy: 0.9771 - val_loss: 0.1130 - val_categorical_accuracy: 0.9907
# Epoch 57/2000
# 65/65 [==============================] - 1s 10ms/step - loss: 0.1390 - categorical_accuracy: 0.9909 - val_loss: 0.1297 - val_categorical_accuracy: 1.0000
# Epoch 58/2000
# 65/65 [==============================] - 1s 8ms/step - loss: 0.1739 - categorical_accuracy: 0.9777 - val_loss: 0.1014 - val_categorical_accuracy: 1.0000
# Epoch 59/2000
# 65/65 [==============================] - 1s 8ms/step - loss: 0.1205 - categorical_accuracy: 0.9923 - val_loss: 0.0986 - val_categorical_accuracy: 1.0000
# Epoch 60/2000
# 65/65 [==============================] - 1s 8ms/step - loss: 0.1065 - categorical_accuracy: 0.9979 - val_loss: 0.1029 - val_categorical_accuracy: 1.0000
# Epoch 61/2000
# 65/65 [==============================] - 1s 8ms/step - loss: 0.1032 - categorical_accuracy: 0.9984 - val_loss: 0.1033 - val_categorical_accuracy: 1.0000
# Epoch 62/2000
# 65/65 [==============================] - 1s 8ms/step - loss: 0.1089 - categorical_accuracy: 0.9963 - val_loss: 0.1115 - val_categorical_accuracy: 0.9907
# Epoch 63/2000
# 65/65 [==============================] - 1s 9ms/step - loss: 0.1168 - categorical_accuracy: 0.9909 - val_loss: 0.0948 - val_categorical_accuracy: 1.0000
# Epoch 64/2000
# 65/65 [==============================] - 1s 9ms/step - loss: 0.1300 - categorical_accuracy: 0.9856 - val_loss: 0.0948 - val_categorical_accuracy: 1.0000
# Epoch 65/2000
# 65/65 [==============================] - 1s 8ms/step - loss: 0.1190 - categorical_accuracy: 0.9912 - val_loss: 0.0912 - val_categorical_accuracy: 1.0000
# Epoch 66/2000
# 65/65 [==============================] - 1s 10ms/step - loss: 0.0977 - categorical_accuracy: 0.9984 - val_loss: 0.1120 - val_categorical_accuracy: 0.9907
# Epoch 67/2000
# 65/65 [==============================] - 1s 8ms/step - loss: 0.1285 - categorical_accuracy: 0.9857 - val_loss: 0.0927 - val_categorical_accuracy: 1.0000
# Epoch 68/2000
# 65/65 [==============================] - 0s 8ms/step - loss: 0.1033 - categorical_accuracy: 0.9939 - val_loss: 0.0911 - val_categorical_accuracy: 1.0000
# Epoch 69/2000
# 65/65 [==============================] - 1s 8ms/step - loss: 0.0939 - categorical_accuracy: 0.9969 - val_loss: 0.0880 - val_categorical_accuracy: 1.0000
# Epoch 70/2000
# 65/65 [==============================] - 1s 8ms/step - loss: 0.0966 - categorical_accuracy: 0.9982 - val_loss: 0.0886 - val_categorical_accuracy: 1.0000
# Epoch 71/2000
# 65/65 [==============================] - 1s 8ms/step - loss: 0.0908 - categorical_accuracy: 0.9986 - val_loss: 0.0868 - val_categorical_accuracy: 1.0000
# Epoch 72/2000
# 65/65 [==============================] - 1s 9ms/step - loss: 0.0943 - categorical_accuracy: 0.9975 - val_loss: 0.0888 - val_categorical_accuracy: 1.0000
# Epoch 73/2000
# 65/65 [==============================] - 1s 9ms/step - loss: 0.0892 - categorical_accuracy: 0.9986 - val_loss: 0.0896 - val_categorical_accuracy: 1.0000
# Epoch 74/2000
# 65/65 [==============================] - 1s 8ms/step - loss: 0.0874 - categorical_accuracy: 0.9992 - val_loss: 0.2710 - val_categorical_accuracy: 0.9630
# Epoch 75/2000
# 65/65 [==============================] - 0s 8ms/step - loss: 0.2259 - categorical_accuracy: 0.9626 - val_loss: 0.0912 - val_categorical_accuracy: 1.0000
# Epoch 76/2000
# 65/65 [==============================] - 1s 9ms/step - loss: 0.1101 - categorical_accuracy: 0.9929 - val_loss: 0.1245 - val_categorical_accuracy: 0.9907
# Epoch 77/2000
# 65/65 [==============================] - 1s 8ms/step - loss: 0.0974 - categorical_accuracy: 0.9964 - val_loss: 0.0837 - val_categorical_accuracy: 1.0000
# Epoch 78/2000
# 65/65 [==============================] - 1s 9ms/step - loss: 0.0868 - categorical_accuracy: 0.9993 - val_loss: 0.0824 - val_categorical_accuracy: 1.0000
# Epoch 79/2000
# 65/65 [==============================] - 1s 8ms/step - loss: 0.0910 - categorical_accuracy: 0.9970 - val_loss: 0.0815 - val_categorical_accuracy: 1.0000
# Epoch 80/2000
# 65/65 [==============================] - 1s 10ms/step - loss: 0.0862 - categorical_accuracy: 0.9972 - val_loss: 0.0806 - val_categorical_accuracy: 1.0000
# Epoch 81/2000
# 65/65 [==============================] - 1s 9ms/step - loss: 0.0830 - categorical_accuracy: 0.9988 - val_loss: 0.0797 - val_categorical_accuracy: 1.0000
# Epoch 82/2000
# 65/65 [==============================] - 1s 11ms/step - loss: 0.0836 - categorical_accuracy: 0.9990 - val_loss: 0.0790 - val_categorical_accuracy: 1.0000
# Epoch 83/2000
# 65/65 [==============================] - 1s 8ms/step - loss: 0.0830 - categorical_accuracy: 0.9981 - val_loss: 0.0783 - val_categorical_accuracy: 1.0000
# Epoch 84/2000
# 65/65 [==============================] - 1s 9ms/step - loss: 0.0811 - categorical_accuracy: 0.9988 - val_loss: 0.0777 - val_categorical_accuracy: 1.0000
# Epoch 85/2000
# 65/65 [==============================] - 1s 8ms/step - loss: 0.0801 - categorical_accuracy: 0.9991 - val_loss: 0.0770 - val_categorical_accuracy: 1.0000
# Epoch 86/2000
# 65/65 [==============================] - 1s 9ms/step - loss: 0.0806 - categorical_accuracy: 0.9990 - val_loss: 0.0764 - val_categorical_accuracy: 1.0000
# Epoch 87/2000
# 65/65 [==============================] - 1s 9ms/step - loss: 0.0794 - categorical_accuracy: 0.9988 - val_loss: 0.0763 - val_categorical_accuracy: 1.0000
# Epoch 88/2000
# 65/65 [==============================] - 1s 9ms/step - loss: 0.0799 - categorical_accuracy: 0.9988 - val_loss: 0.0753 - val_categorical_accuracy: 1.0000
# Epoch 89/2000
# 65/65 [==============================] - 1s 9ms/step - loss: 0.0775 - categorical_accuracy: 0.9991 - val_loss: 0.0747 - val_categorical_accuracy: 1.0000
# Epoch 90/2000
# 65/65 [==============================] - 1s 9ms/step - loss: 0.0769 - categorical_accuracy: 0.9988 - val_loss: 0.0743 - val_categorical_accuracy: 1.0000
# Epoch 91/2000
# 65/65 [==============================] - 1s 10ms/step - loss: 0.0754 - categorical_accuracy: 0.9997 - val_loss: 0.0736 - val_categorical_accuracy: 1.0000
# Epoch 92/2000
# 65/65 [==============================] - 1s 9ms/step - loss: 0.0812 - categorical_accuracy: 0.9949 - val_loss: 0.0730 - val_categorical_accuracy: 1.0000
# Epoch 93/2000
# 65/65 [==============================] - 1s 9ms/step - loss: 0.0754 - categorical_accuracy: 0.9992 - val_loss: 0.0726 - val_categorical_accuracy: 1.0000
# Epoch 94/2000
# 65/65 [==============================] - 1s 9ms/step - loss: 0.0772 - categorical_accuracy: 0.9983 - val_loss: 0.0719 - val_categorical_accuracy: 1.0000
# Epoch 95/2000
# 65/65 [==============================] - 1s 9ms/step - loss: 0.0770 - categorical_accuracy: 0.9955 - val_loss: 0.0714 - val_categorical_accuracy: 1.0000
# Epoch 96/2000
# 65/65 [==============================] - 0s 8ms/step - loss: 0.0797 - categorical_accuracy: 0.9972 - val_loss: 0.0723 - val_categorical_accuracy: 1.0000
# Epoch 97/2000
# 65/65 [==============================] - 1s 9ms/step - loss: 0.2692 - categorical_accuracy: 0.9504 - val_loss: 0.1353 - val_categorical_accuracy: 0.9815
# Epoch 98/2000
# 65/65 [==============================] - 1s 9ms/step - loss: 0.1407 - categorical_accuracy: 0.9796 - val_loss: 0.1233 - val_categorical_accuracy: 0.9815
# Epoch 99/2000
# 65/65 [==============================] - 1s 9ms/step - loss: 0.1341 - categorical_accuracy: 0.9827 - val_loss: 0.0916 - val_categorical_accuracy: 0.9907
# Epoch 100/2000
# 65/65 [==============================] - 1s 9ms/step - loss: 0.0900 - categorical_accuracy: 0.9956 - val_loss: 0.0750 - val_categorical_accuracy: 1.0000
# Epoch 101/2000
# 65/65 [==============================] - 1s 9ms/step - loss: 0.0803 - categorical_accuracy: 0.9981 - val_loss: 0.0712 - val_categorical_accuracy: 1.0000
# Epoch 102/2000
# 65/65 [==============================] - 1s 8ms/step - loss: 0.0741 - categorical_accuracy: 0.9989 - val_loss: 0.0705 - val_categorical_accuracy: 1.0000
# Epoch 103/2000
# 65/65 [==============================] - 1s 9ms/step - loss: 0.0727 - categorical_accuracy: 0.9992 - val_loss: 0.0698 - val_categorical_accuracy: 1.0000
# Epoch 104/2000
# 65/65 [==============================] - 1s 9ms/step - loss: 0.0736 - categorical_accuracy: 0.9983 - val_loss: 0.0691 - val_categorical_accuracy: 1.0000
# Epoch 105/2000
# 65/65 [==============================] - 1s 9ms/step - loss: 0.0744 - categorical_accuracy: 0.9978 - val_loss: 0.0689 - val_categorical_accuracy: 1.0000
# Epoch 106/2000
# 65/65 [==============================] - 1s 10ms/step - loss: 0.0728 - categorical_accuracy: 0.9991 - val_loss: 0.0683 - val_categorical_accuracy: 1.0000
# Epoch 107/2000
# 65/65 [==============================] - 1s 10ms/step - loss: 0.0723 - categorical_accuracy: 0.9980 - val_loss: 0.0678 - val_categorical_accuracy: 1.0000
# Epoch 108/2000
# 65/65 [==============================] - 1s 9ms/step - loss: 0.0692 - categorical_accuracy: 0.9991 - val_loss: 0.0672 - val_categorical_accuracy: 1.0000
# Epoch 109/2000
# 65/65 [==============================] - 1s 8ms/step - loss: 0.0717 - categorical_accuracy: 0.9974 - val_loss: 0.0669 - val_categorical_accuracy: 1.0000
# Epoch 110/2000
# 65/65 [==============================] - 1s 8ms/step - loss: 0.0714 - categorical_accuracy: 0.9976 - val_loss: 0.0664 - val_categorical_accuracy: 1.0000
# Epoch 111/2000
# 65/65 [==============================] - 1s 9ms/step - loss: 0.0685 - categorical_accuracy: 0.9987 - val_loss: 0.0660 - val_categorical_accuracy: 1.0000
# Epoch 112/2000
# 65/65 [==============================] - 1s 10ms/step - loss: 0.0676 - categorical_accuracy: 0.9991 - val_loss: 0.0656 - val_categorical_accuracy: 1.0000
# Epoch 113/2000
# 65/65 [==============================] - 1s 8ms/step - loss: 0.0673 - categorical_accuracy: 0.9990 - val_loss: 0.0656 - val_categorical_accuracy: 1.0000
# Epoch 114/2000
# 65/65 [==============================] - 1s 9ms/step - loss: 0.0692 - categorical_accuracy: 0.9982 - val_loss: 0.0648 - val_categorical_accuracy: 1.0000
# Epoch 115/2000
# 65/65 [==============================] - 1s 9ms/step - loss: 0.0666 - categorical_accuracy: 0.9996 - val_loss: 0.0644 - val_categorical_accuracy: 1.0000
# Epoch 116/2000
# 65/65 [==============================] - 1s 8ms/step - loss: 0.0664 - categorical_accuracy: 0.9993 - val_loss: 0.0640 - val_categorical_accuracy: 1.0000
# Epoch 117/2000
# 65/65 [==============================] - 1s 9ms/step - loss: 0.0698 - categorical_accuracy: 0.9982 - val_loss: 0.0737 - val_categorical_accuracy: 0.9907
# Epoch 118/2000
# 65/65 [==============================] - 1s 9ms/step - loss: 0.0749 - categorical_accuracy: 0.9980 - val_loss: 0.0638 - val_categorical_accuracy: 1.0000
# Epoch 119/2000
# 65/65 [==============================] - 1s 9ms/step - loss: 0.0718 - categorical_accuracy: 0.9941 - val_loss: 0.0636 - val_categorical_accuracy: 1.0000
# Epoch 120/2000
# 65/65 [==============================] - 1s 11ms/step - loss: 0.1663 - categorical_accuracy: 0.9719 - val_loss: 0.1065 - val_categorical_accuracy: 0.9907
# Epoch 121/2000
# 65/65 [==============================] - 1s 10ms/step - loss: 0.1149 - categorical_accuracy: 0.9861 - val_loss: 0.0746 - val_categorical_accuracy: 1.0000
# Epoch 122/2000
# 65/65 [==============================] - 1s 8ms/step - loss: 0.1131 - categorical_accuracy: 0.9879 - val_loss: 0.0709 - val_categorical_accuracy: 1.0000
# Epoch 123/2000
# 65/65 [==============================] - 0s 8ms/step - loss: 0.1112 - categorical_accuracy: 0.9816 - val_loss: 0.0678 - val_categorical_accuracy: 1.0000
# Epoch 124/2000
# 65/65 [==============================] - 1s 8ms/step - loss: 0.0818 - categorical_accuracy: 0.9945 - val_loss: 0.0643 - val_categorical_accuracy: 1.0000
# Epoch 125/2000
# 65/65 [==============================] - 1s 8ms/step - loss: 0.0677 - categorical_accuracy: 0.9977 - val_loss: 0.0637 - val_categorical_accuracy: 1.0000
# Epoch 126/2000
# 65/65 [==============================] - 0s 8ms/step - loss: 0.0676 - categorical_accuracy: 0.9979 - val_loss: 0.0623 - val_categorical_accuracy: 1.0000
# Epoch 127/2000
# 65/65 [==============================] - 1s 9ms/step - loss: 0.0656 - categorical_accuracy: 0.9979 - val_loss: 0.0619 - val_categorical_accuracy: 1.0000
# Epoch 128/2000
# 65/65 [==============================] - 1s 8ms/step - loss: 0.0632 - categorical_accuracy: 0.9994 - val_loss: 0.0614 - val_categorical_accuracy: 1.0000
# Epoch 129/2000
# 65/65 [==============================] - 1s 8ms/step - loss: 0.0648 - categorical_accuracy: 0.9975 - val_loss: 0.0617 - val_categorical_accuracy: 1.0000
# Epoch 130/2000
# 65/65 [==============================] - 1s 9ms/step - loss: 0.0648 - categorical_accuracy: 0.9984 - val_loss: 0.0607 - val_categorical_accuracy: 1.0000
# Epoch 131/2000
# 65/65 [==============================] - 1s 8ms/step - loss: 0.0616 - categorical_accuracy: 0.9998 - val_loss: 0.0605 - val_categorical_accuracy: 1.0000
# Epoch 132/2000
# 65/65 [==============================] - 1s 10ms/step - loss: 0.0613 - categorical_accuracy: 0.9997 - val_loss: 0.0602 - val_categorical_accuracy: 1.0000
# Epoch 133/2000
# 65/65 [==============================] - 1s 9ms/step - loss: 0.0618 - categorical_accuracy: 0.9991 - val_loss: 0.0598 - val_categorical_accuracy: 1.0000
# Epoch 134/2000
# 58/65 [=========================>....] - ETA: 0s - loss: 0.0626 - categorical_accuracy: 0.9983
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-7-794c3a7c9556> in <module>
# ----> 1 model.fit(X_train, y_train, epochs=2000, validation_data=(X_test, y_test), callbacks=[tb_callback], shuffle=True)
#
# d:\Anaconda\package\lib\site-packages\tensorflow\python\keras\engine\training.py in fit(self, x, y, batch_size, epochs, verbose, callbacks, validation_split, validation_data, shuffle, class_weight, sample_weight, initial_epoch, steps_per_epoch, validation_steps, validation_batch_size, validation_freq, max_queue_size, workers, use_multiprocessing)
#    1129                 model=self,
#    1130                 steps_per_execution=self._steps_per_execution)
# -> 1131           val_logs = self.evaluate(
#    1132               x=val_x,
#    1133               y=val_y,
#
# d:\Anaconda\package\lib\site-packages\tensorflow\python\keras\engine\training.py in evaluate(self, x, y, batch_size, verbose, sample_weight, steps, callbacks, max_queue_size, workers, use_multiprocessing, return_dict)
#    1387             with trace.Trace('test', step_num=step, _r=1):
#    1388               callbacks.on_test_batch_begin(step)
# -> 1389               tmp_logs = self.test_function(iterator)
#    1390               if data_handler.should_sync:
#    1391                 context.async_wait()
#
# d:\Anaconda\package\lib\site-packages\tensorflow\python\eager\def_function.py in __call__(self, *args, **kwds)
#     826     tracing_count = self.experimental_get_tracing_count()
#     827     with trace.Trace(self._name) as tm:
# --> 828       result = self._call(*args, **kwds)
#     829       compiler = "xla" if self._experimental_compile else "nonXla"
#     830       new_tracing_count = self.experimental_get_tracing_count()
#
# d:\Anaconda\package\lib\site-packages\tensorflow\python\eager\def_function.py in _call(self, *args, **kwds)
#     860       # In this case we have not created variables on the first call. So we can
#     861       # run the first trace but we should fail if variables are created.
# --> 862       results = self._stateful_fn(*args, **kwds)
#     863       if self._created_variables:
#     864         raise ValueError("Creating variables on a non-first call to a function"
#
# d:\Anaconda\package\lib\site-packages\tensorflow\python\eager\function.py in __call__(self, *args, **kwargs)
#    2940       (graph_function,
#    2941        filtered_flat_args) = self._maybe_define_function(args, kwargs)
# -> 2942     return graph_function._call_flat(
#    2943         filtered_flat_args, captured_inputs=graph_function.captured_inputs)  # pylint: disable=protected-access
#    2944
#
# d:\Anaconda\package\lib\site-packages\tensorflow\python\eager\function.py in _call_flat(self, args, captured_inputs, cancellation_manager)
#    1916         and executing_eagerly):
#    1917       # No tape is watching; skip to running the function.
# -> 1918       return self._build_call_outputs(self._inference_function.call(
#    1919           ctx, args, cancellation_manager=cancellation_manager))
#    1920     forward_backward = self._select_forward_and_backward_functions(
#
# d:\Anaconda\package\lib\site-packages\tensorflow\python\eager\function.py in call(self, ctx, args, cancellation_manager)
#     553       with _InterpolateFunctionError(self):
#     554         if cancellation_manager is None:
# --> 555           outputs = execute.execute(
#     556               str(self.signature.name),
#     557               num_outputs=self._num_outputs,
#
# d:\Anaconda\package\lib\site-packages\tensorflow\python\eager\execute.py in quick_execute(op_name, num_outputs, inputs, attrs, ctx, name)
#      57   try:
#      58     ctx.ensure_initialized()
# ---> 59     tensors = pywrap_tfe.TFE_Py_Execute(ctx._handle, device_name, op_name,
#      60                                         inputs, attrs, num_outputs)
#      61   except core._NotOkStatusException as e:
#
# KeyboardInterrupt:

# %%
plt.plot(model.history.history['loss'])
plt.plot(model.history.history['val_loss'])
plt.title('model train vs validation loss')
plt.ylabel('loss')
plt.xlabel('epoch')
plt.legend(['train', 'validation'], loc='upper right')
plt.show()

# %%
plt.plot(model.history.history['categorical_accuracy'])
plt.plot(model.history.history['val_categorical_accuracy'])
plt.title('model train vs validation accuracy')
plt.ylabel('accuracy')
plt.xlabel('epoch')
plt.legend(['train', 'validation'], loc='lower right')
plt.show()

# %%
model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# lstm (LSTM)                  (None, 5, 64)             48896
# _________________________________________________________________
# lstm_1 (LSTM)                (None, 5, 128)            98816
# _________________________________________________________________
# lstm_2 (LSTM)                (None, 64)                49408
# _________________________________________________________________
# dense (Dense)                (None, 64)                4160
# _________________________________________________________________
# dense_1 (Dense)              (None, 32)                2080
# _________________________________________________________________
# dense_2 (Dense)              (None, 6)                 198
# =================================================================
# Total params: 203,558
# Trainable params: 203,558
# Non-trainable params: 0
# _________________________________________________________________

# %%
model.save('action.h5')
